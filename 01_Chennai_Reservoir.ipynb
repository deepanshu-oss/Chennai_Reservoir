# %% [markdown]
# This project is about analyzing water levels in Chennai
#
# ### Import reqiured Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
chennai = pd.read_csv('chennai_reservoir_levels.csv')
chennai.tail()
# Out:
#             Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 5642  13-06-2019    30.0         0.0       0.0              1.0
# 5643  14-06-2019    28.0         0.0       0.0              1.0
# 5644  15-06-2019    27.0         0.0       0.0              1.0
# 5645  16-06-2019    26.0         0.0       0.0              1.0
# 5646  17-06-2019    25.0         0.0       0.0              1.0

# %%
chennai
# Out:
#             Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 0     01-01-2004     3.9         0.0     268.0              0.0
# 1     02-01-2004     3.9         0.0     268.0              0.0
# 2     03-01-2004     3.9         0.0     267.0              0.0
# 3     04-01-2004     3.9         0.0     267.0              0.0
# 4     05-01-2004     3.8         0.0     267.0              0.0
# ...          ...     ...         ...       ...              ...
# 5642  13-06-2019    30.0         0.0       0.0              1.0
# 5643  14-06-2019    28.0         0.0       0.0              1.0
# 5644  15-06-2019    27.0         0.0       0.0              1.0
# 5645  16-06-2019    26.0         0.0       0.0              1.0
# 5646  17-06-2019    25.0         0.0       0.0              1.0
#
# [5647 rows x 5 columns]

# %%
chennai.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5647 entries, 0 to 5646
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             5647 non-null   object
#  1   POONDI           5647 non-null   float64
#  2   CHOLAVARAM       5647 non-null   float64
#  3   REDHILLS         5647 non-null   float64
#  4   CHEMBARAMBAKKAM  5647 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 220.7+ KB

# %%
import datetime

# %%
chennai['Date'] = pd.to_datetime(chennai['Date'],format = '%d-%m-%Y')

# %%
chennai['Date']
# Out:
# 0      2004-01-01
# 1      2004-01-02
# 2      2004-01-03
# 3      2004-01-04
# 4      2004-01-05
#           ...
# 5642   2019-06-13
# 5643   2019-06-14
# 5644   2019-06-15
# 5645   2019-06-16
# 5646   2019-06-17
# Name: Date, Length: 5647, dtype: datetime64[ns]

# %%
chennai['Date'].dt.month
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5642    6
# 5643    6
# 5644    6
# 5645    6
# 5646    6
# Name: Date, Length: 5647, dtype: int32

# %%
chennai.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5647 entries, 0 to 5646
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             5647 non-null   datetime64[ns]
#  1   POONDI           5647 non-null   float64
#  2   CHOLAVARAM       5647 non-null   float64
#  3   REDHILLS         5647 non-null   float64
#  4   CHEMBARAMBAKKAM  5647 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 220.7 KB

# %%
chennai['month'] = chennai['Date'].apply(lambda x:x.month)

# %%
chennai.head()
# Out:
#         Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM  month
# 0 2004-01-01     3.9         0.0     268.0              0.0      1
# 1 2004-01-02     3.9         0.0     268.0              0.0      1
# 2 2004-01-03     3.9         0.0     267.0              0.0      1
# 3 2004-01-04     3.9         0.0     267.0              0.0      1
# 4 2004-01-05     3.8         0.0     267.0              0.0      1

# %%
chennai['Year'] = chennai['Date'].apply(lambda x :x.year)

# %%
chennai.head()
# Out:
#         Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM  month  Year
# 0 2004-01-01     3.9         0.0     268.0              0.0      1  2004
# 1 2004-01-02     3.9         0.0     268.0              0.0      1  2004
# 2 2004-01-03     3.9         0.0     267.0              0.0      1  2004
# 3 2004-01-04     3.9         0.0     267.0              0.0      1  2004
# 4 2004-01-05     3.8         0.0     267.0              0.0      1  2004

# %%
chennai.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5647 entries, 0 to 5646
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             5647 non-null   datetime64[ns]
#  1   POONDI           5647 non-null   float64
#  2   CHOLAVARAM       5647 non-null   float64
#  3   REDHILLS         5647 non-null   float64
#  4   CHEMBARAMBAKKAM  5647 non-null   float64
#  5   month            5647 non-null   int64
#  6   Year             5647 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(2)
# memory usage: 308.9 KB

# %%
chennai['Date'][0].month
# Out:
# 1

# %%
chennai['Date'][0].year
# Out:
# 2004

# %%
chennai['Date'][0].day
# Out:
# 1

# %%
chennai['Total'] = chennai[['POONDI','CHOLAVARAM','REDHILLS','CHEMBARAMBAKKAM']].sum(axis =1)

# %%
chennai.head()
# Out:
#         Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM  month  Year  \
# 0 2004-01-01     3.9         0.0     268.0              0.0      1  2004
# 1 2004-01-02     3.9         0.0     268.0              0.0      1  2004
# 2 2004-01-03     3.9         0.0     267.0              0.0      1  2004
# 3 2004-01-04     3.9         0.0     267.0              0.0      1  2004
# 4 2004-01-05     3.8         0.0     267.0              0.0      1  2004
#
#    Total
# 0  271.9
# 1  271.9
# 2  270.9
# 3  270.9
# 4  270.8

# %%
chennai[['POONDI','CHOLAVARAM','REDHILLS','CHEMBARAMBAKKAM','Year']].groupby('Year').mean()
# Out:
#            POONDI  CHOLAVARAM     REDHILLS  CHEMBARAMBAKKAM
# Year
# 2004    77.766967   19.060109   220.899180        68.683060
# 2005   722.680603  147.771781  1468.480712       581.345205
# 2006  1827.553425  484.947945  2044.356164      2075.317808
# 2007  1794.912329  286.391781  2356.654795      1715.126027
# 2008  1862.338798  545.609290  2445.161202      2196.967213
# 2009  1846.221918  414.882110  1969.731205      1795.677123
# 2010  1651.523288  382.175342  2045.271233      2020.501370
# 2011  2399.068493  499.509589  2573.326027      2492.282192
# 2012  1742.816940  225.934426  1872.218579      1571.677596
# 2013   536.953425  100.049315  1324.109589       988.964384
# 2014   311.441096   38.917808  1480.350685       913.715068
# 2015   495.408219  122.278082  1168.942466       881.317808
# 2016  1115.937158  182.748634  1412.098361      1730.360656
# 2017   341.361644  112.167123   486.435616       466.117808
# 2018   641.257534  128.726027  1154.073973       873.315068
# ...

# %%
Yearwise= chennai[['POONDI','CHOLAVARAM','REDHILLS','CHEMBARAMBAKKAM','Year','Total']].groupby('Year',as_index = False).mean()

# %%
Monthwise= chennai[['POONDI','CHOLAVARAM','REDHILLS','CHEMBARAMBAKKAM','month','Total']].groupby('month',as_index = False).mean()

# %%
Monthwise
# Out:
#     month       POONDI  CHOLAVARAM     REDHILLS  CHEMBARAMBAKKAM        Total
# 0       1  1774.628629  453.087702  2049.701613      1760.641129  6038.059073
# 1       2  1621.638053  381.133186  2002.247788      1601.225664  5606.244690
# 2       3  1457.505565  300.006048  1950.056452      1507.070565  5214.638629
# 3       4  1204.701667  202.635417  1763.093958      1354.150000  4524.581042
# 4       5   947.485887  148.365927  1488.105444      1245.379032  3829.336290
# 5       6   719.382441  101.877944  1322.688223      1134.689507  3278.638116
# 6       7   533.537419   90.434409  1179.418495      1017.574194  2820.964516
# 7       8   479.559570   75.539785  1068.748387       923.808602  2547.656344
# 8       9   665.000956   83.397778  1046.349911       905.124444  2699.873089
# 9      10   891.648473  136.834409  1087.332839       930.800000  3046.615720
# 10     11  1388.374222  390.694756  1685.440800      1531.418800  4995.928578
# ...

# %%
Yearwise.head()
# Out:
#    Year       POONDI  CHOLAVARAM     REDHILLS  CHEMBARAMBAKKAM        Total
# 0  2004    77.766967   19.060109   220.899180        68.683060   386.409317
# 1  2005   722.680603  147.771781  1468.480712       581.345205  2920.278301
# 2  2006  1827.553425  484.947945  2044.356164      2075.317808  6432.175342
# 3  2007  1794.912329  286.391781  2356.654795      1715.126027  6153.084932
# 4  2008  1862.338798  545.609290  2445.161202      2196.967213  7050.076503

# %%
Monthwise.head()
# Out:
#    month       POONDI  CHOLAVARAM     REDHILLS  CHEMBARAMBAKKAM        Total
# 0      1  1774.628629  453.087702  2049.701613      1760.641129  6038.059073
# 1      2  1621.638053  381.133186  2002.247788      1601.225664  5606.244690
# 2      3  1457.505565  300.006048  1950.056452      1507.070565  5214.638629
# 3      4  1204.701667  202.635417  1763.093958      1354.150000  4524.581042
# 4      5   947.485887  148.365927  1488.105444      1245.379032  3829.336290

# %%
plt.figure(figsize= (12,4))
sns.barplot(x = 'Year',y = 'Total',data = Yearwise)
plt.title('Mean Yearly waterlevel in all the four reservoir')
plt.show()

# %%
plt.figure(figsize= (12,4))
ax = sns.barplot(x = 'Year',y = 'Total',data = Yearwise)
ax.bar_label(ax.containers[0],fontsize = 8)
plt.title('Mean Yearly waterlevel in all the four reservoir')
plt.show()

# %%
plt.figure(figsize = (20,10))
Yearwise.plot.line(x = 'Year',y = ['POONDI','CHOLAVARAM','REDHILLS','CHEMBARAMBAKKAM','Total'])
plt.show()

# %%
plt.figure(figsize = (20,10))
Yearwise.plot(x = 'Year',y = ['POONDI','CHOLAVARAM','REDHILLS','CHEMBARAMBAKKAM','Total'],kind = 'line')
plt.show()

# %%
sns.lineplot(x = 'Year',y ='Total',data = Yearwise)
# Out:
# C:\Users\Deepa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Deepa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Year', ylabel='Total'>

# %%
Yearwise1 = Yearwise.set_index('Year')

# %%
Yearwise1
# Out:
#            POONDI  CHOLAVARAM     REDHILLS  CHEMBARAMBAKKAM        Total
# Year
# 2004    77.766967   19.060109   220.899180        68.683060   386.409317
# 2005   722.680603  147.771781  1468.480712       581.345205  2920.278301
# 2006  1827.553425  484.947945  2044.356164      2075.317808  6432.175342
# 2007  1794.912329  286.391781  2356.654795      1715.126027  6153.084932
# 2008  1862.338798  545.609290  2445.161202      2196.967213  7050.076503
# 2009  1846.221918  414.882110  1969.731205      1795.677123  6026.512356
# 2010  1651.523288  382.175342  2045.271233      2020.501370  6099.471233
# 2011  2399.068493  499.509589  2573.326027      2492.282192  7964.186301
# 2012  1742.816940  225.934426  1872.218579      1571.677596  5412.647541
# 2013   536.953425  100.049315  1324.109589       988.964384  2950.076712
# 2014   311.441096   38.917808  1480.350685       913.715068  2744.424658
# 2015   495.408219  122.278082  1168.942466       881.317808  2667.946575
# ...

# %%
sns.lineplot(data = Yearwise1[['POONDI','CHOLAVARAM','REDHILLS','CHEMBARAMBAKKAM']])
# Out:
# C:\Users\Deepa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Deepa\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Year'>

# %%
chennai['month']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 5642    6
# 5643    6
# 5644    6
# 5645    6
# 5646    6
# Name: month, Length: 5647, dtype: int64

# %%
chennai['month'] = pd.Categorical(chennai['month'])

# %%
chennai.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5647 entries, 0 to 5646
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             5647 non-null   datetime64[ns]
#  1   POONDI           5647 non-null   float64
#  2   CHOLAVARAM       5647 non-null   float64
#  3   REDHILLS         5647 non-null   float64
#  4   CHEMBARAMBAKKAM  5647 non-null   float64
#  5   month            5647 non-null   category
#  6   Year             5647 non-null   int64
#  7   Total            5647 non-null   float64
# dtypes: category(1), datetime64[ns](1), float64(5), int64(1)
# memory usage: 314.9 KB

# %%
chennai
# Out:
#            Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM month  Year  \
# 0    2004-01-01     3.9         0.0     268.0              0.0     1  2004
# 1    2004-01-02     3.9         0.0     268.0              0.0     1  2004
# 2    2004-01-03     3.9         0.0     267.0              0.0     1  2004
# 3    2004-01-04     3.9         0.0     267.0              0.0     1  2004
# 4    2004-01-05     3.8         0.0     267.0              0.0     1  2004
# ...         ...     ...         ...       ...              ...   ...   ...
# 5642 2019-06-13    30.0         0.0       0.0              1.0     6  2019
# 5643 2019-06-14    28.0         0.0       0.0              1.0     6  2019
# 5644 2019-06-15    27.0         0.0       0.0              1.0     6  2019
# 5645 2019-06-16    26.0         0.0       0.0              1.0     6  2019
# 5646 2019-06-17    25.0         0.0       0.0              1.0     6  2019
#
#       Total
# 0     271.9
# 1     271.9
# 2     270.9
# 3     270.9
# ...

# %%
plt.figure(figsize = (20,10))
sns.barplot(x = 'Year',y = 'Total',data = chennai)
# Out:
# <Axes: xlabel='Year', ylabel='Total'>

# %%
plt.figure(figsize = (14,5))
sns.barplot(x ='Year',y ='Total',data = chennai,hue = 'month')
plt.title('Mean Yearly waterlevel in all the four reservoir')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[110], line 2
#       1 plt.figure(figsize = (14,5))
# ----> 2 sns.barplot(x ='Year',y ='Total',data = chennai,hue = 'month')
#       3 plt.title('Mean Yearly waterlevel in all the four reservoir')
#       4 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:2763, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2760 if ax is None:
#    2761     ax = plt.gca()
# -> 2763 plotter.plot(ax, kwargs)
#    2764 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
# ...

# %%
jan = chennai[chennai['month']==1]
jan

# %%
plt.figure(figsize = (12,8))
sns.barplot(x = 'Year',y = 'Total',data = jan)

# %% [markdown]
# ### Inferences
#
# * Although Chennai receive some rainfall in July , Aug , Sep due to South-West monsoon but majority of the rainfall happens in Nov-Dec due North-East monsoon
# * From 2006 to 2010, North East monsoon had much more contribution than South-West monsoon. In last few years , however, either both SW and NE are contributing equally or SW is contributing more.
# * Declining in NE monsoon rainfall in second half of 2010s

# %% [markdown]
# ### Monthwise comparision

# %%
plt.figure(figsize=(20,10))
ax = sns.barplot(x = 'month',y = 'Total',data = Monthwise)
ax.bar_label(ax.containers[0],fontsize = 15)
plt.show()

# %%
chennai.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5647 entries, 0 to 5646
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             5647 non-null   datetime64[ns]
#  1   POONDI           5647 non-null   float64
#  2   CHOLAVARAM       5647 non-null   float64
#  3   REDHILLS         5647 non-null   float64
#  4   CHEMBARAMBAKKAM  5647 non-null   float64
#  5   month            5647 non-null   category
#  6   Year             5647 non-null   int64
#  7   Total            5647 non-null   float64
# dtypes: category(1), datetime64[ns](1), float64(5), int64(1)
# memory usage: 314.9 KB

# %%
chennai_before_2012 = chennai[chennai['Year']<2012]
chennai_after_2012 = chennai[chennai['Year']>2012]

# %%
chennai_before_2012
# Out:
#            Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM month  Year  \
# 0    2004-01-01     3.9         0.0     268.0              0.0     1  2004
# 1    2004-01-02     3.9         0.0     268.0              0.0     1  2004
# 2    2004-01-03     3.9         0.0     267.0              0.0     1  2004
# 3    2004-01-04     3.9         0.0     267.0              0.0     1  2004
# 4    2004-01-05     3.8         0.0     267.0              0.0     1  2004
# ...         ...     ...         ...       ...              ...   ...   ...
# 2917 2011-12-27  2648.0       852.0    2607.0           2592.0    12  2011
# 2918 2011-12-28  2645.0       848.0    2593.0           2583.0    12  2011
# 2919 2011-12-29  2642.0       844.0    2579.0           2574.0    12  2011
# 2920 2011-12-30  2669.0       852.0    2595.0           2591.0    12  2011
# 2921 2011-12-31  2770.0       855.0    2636.0           2751.0    12  2011
#
#        Total
# 0      271.9
# 1      271.9
# 2      270.9
# ...

# %%
chennai_before_2012 = chennai_before_2012[['POONDI','CHOLAVARAM','REDHILLS','CHEMBARAMBAKKAM','month','Total']].groupby('month',as_index = False).mean()
# Out:
# C:\Users\Deepa\AppData\Local\Temp\ipykernel_14400\3059816722.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   chennai_before_2012 = chennai_before_2012[['POONDI','CHOLAVARAM','REDHILLS','CHEMBARAMBAKKAM','month','Total']].groupby('month',as_index = False).mean()

# %%
chennai_before_2012
# Out:
#    month       POONDI  CHOLAVARAM     REDHILLS  CHEMBARAMBAKKAM        Total
# 0      1  2269.688710  572.453629  2326.137097      2139.608871  7307.888306
# 1      2  2029.364602  542.164602  2264.982301      1944.159292  6780.670796
# 2      3  1840.204677  465.923387  2251.504032      1792.072581  6349.704677
# 3      4  1633.974167  342.862500  2111.983750      1661.233333  5750.053750
# 4      5  1326.959677  262.556452  1839.916532      1458.536290  4887.968952
# 5      6   915.906667  169.104167  1719.905833      1350.370833  4155.287500
# 6      7   677.789919  143.762097  1522.014516      1210.185484  3553.752016
# 7      8   634.279032  119.911290  1418.250000      1141.250000  3313.690323
# 8      9   974.901792  131.325000  1360.181083      1143.116667  3609.524542
# 9     10  1402.195726  210.689516  1387.587782      1209.362903  4209.835927
# 10    11  2009.230833  538.311000  2052.351500      1985.797750  6585.691083
# ...

# %%
chennai_after_2012.head()
# Out:
#            Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM month  Year  \
# 3288 2013-01-01  1520.0       471.0    2164.0           1239.0     1  2013
# 3289 2013-01-02  1523.0       471.0    2166.0           1241.0     1  2013
# 3290 2013-01-03  1525.0       471.0    2169.0           1236.0     1  2013
# 3291 2013-01-04  1527.0       471.0    2171.0           1228.0     1  2013
# 3292 2013-01-05  1529.0       471.0    2173.0           1221.0     1  2013
#
#        Total
# 3288  5394.0
# 3289  5401.0
# 3290  5401.0
# 3291  5397.0
# 3292  5394.0

# %%
chennai_after_2012 = chennai_after_2012[['POONDI','CHOLAVARAM','REDHILLS','CHEMBARAMBAKKAM','month','Total']].groupby('month',as_index = False).mean()
# Out:
# C:\Users\Deepa\AppData\Local\Temp\ipykernel_14400\179939801.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   chennai_after_2012 = chennai_after_2012[['POONDI','CHOLAVARAM','REDHILLS','CHEMBARAMBAKKAM','month','Total']].groupby('month',as_index = False).mean()

# %%
chennai_after_2012
# Out:
#    month       POONDI  CHOLAVARAM     REDHILLS  CHEMBARAMBAKKAM        Total
# 0      1  1024.470046  282.110599  1636.188940      1172.990783  4115.760369
# 1      2   956.487310  192.883249  1600.624365      1066.593909  3816.588832
# 2      3   841.239631  124.036866  1535.078341      1081.783410  3582.138249
# 3      4   533.028571   58.638095  1322.047619       942.209524  2855.923810
# 4      5   333.686636   27.103687  1072.649770       981.907834  2415.347926
# 5      6   292.116751   22.832487   865.959391       895.284264  2076.192893
# 6      7   205.376344   20.236559   702.650538       777.741935  1706.005376
# 7      8   222.268817   14.801075   550.387097       576.236559  1363.693548
# 8      9   256.355556   18.527778   560.300000       514.272222  1349.455556
# 9     10   259.623656   40.263441   593.188172       532.666667  1425.741935
# 10    11   644.355556  204.600000  1143.766667       975.655556  2968.377778
# ...

# %%
# Here we are going to compare the water levels between months before 2012 and
# after 2012

# %%
plt.figure(figsize=(15,5))
ax = sns.barplot(x = 'month',y = 'Total',data = chennai_before_2012)
ax.bar_label(ax.containers[0],fontsize = 10)
plt.show()
# Out:
# C:\Users\Deepa\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
plt.figure(figsize=(15,5))
ax = sns.barplot(x = 'month',y = 'Total',data = chennai_after_2012)
ax.bar_label(ax.containers[0],fontsize = 10)
plt.show()
# Out:
# C:\Users\Deepa\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
